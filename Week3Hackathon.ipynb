# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier

# %%
# Load datasets
train_df = pd.read_csv("hacktrain.csv")
test_df = pd.read_csv("hacktest.csv")

# %%
ndvi_columns = [col for col in train_df.columns if col.endswith("_N")]

# %%
def fill_missing_values(df, feature_cols):
    """
    Fills missing values in the specified feature columns of a DataFrame
    using linear interpolation along the rows (axis=1).
    """
    df[feature_cols] = df[feature_cols].interpolate(method='linear', axis=1, limit_direction='both')
    
    # If any NaNs remain (e.g., a whole row was NaN), fill them with 0.
    df[feature_cols] = df[feature_cols].fillna(0)
    return df

# %%
print(train_df.isnull().sum())
# Out:
# Unnamed: 0       0
# ID               0
# class            0
# 20150720_N     560
# 20150602_N    1200
# 20150517_N     800
# 20150501_N     960
# 20150415_N     480
# 20150330_N    1120
# 20150314_N     720
# 20150226_N    1360
# 20150210_N     640
# 20150125_N    1040
# 20150109_N     880
# 20141117_N    1280
# 20141101_N     400
# 20141016_N    1440
# 20140930_N     800
# 20140813_N     560
# 20140626_N    1600
# 20140610_N     480
# 20140525_N     720
# 20140509_N     880
# 20140423_N    1760
# 20140407_N     640
# 20140322_N    1120
# 20140218_N    1440
# 20140202_N     560
# 20140117_N    1200
# 20140101_N     400
# dtype: int64

# %%
train_df = fill_missing_values(train_df, ndvi_columns)
print(train_df)
# Out:
#       Unnamed: 0     ID       class  20150720_N   20150602_N   20150517_N  \
# 0              0      1       water    637.5950   658.668000 -1882.030000
# 1              1      2       water    634.2400   593.705000 -1625.790000
# 2              3      4       water     58.0174 -1599.160000 -1325.895000
# 3              4      5       water     72.5180   226.477000   380.436000
# 4              7      8       water   1136.4400  1306.903333  1477.366667
# ...          ...    ...         ...         ...          ...          ...
# 7995       10537  10538  impervious   1207.7000   984.620000  1075.435000
# 7996       10538  10539  impervious   2170.3500  1419.720000  1361.000000
# 7997       10541  10542  impervious   1895.6800  1454.740000  1244.150000
# 7998       10542  10543  impervious   3465.7400  1283.320000   413.412000
# 7999       10544  10545  impervious   6941.1900  1667.870000  5084.780000
#
#       20150501_N  20150415_N  20150330_N  20150314_N  ...  20140610_N  \
# 0      -1924.360     997.904   -1739.990     630.087  ...   -193.6950
# 1      -1672.320     914.198    -692.386     707.626  ...   -133.6655
# 2      -1052.630   -1308.630   -1564.630    -417.420  ...  -1025.8800
# 3      -1256.930     515.805   -1413.180    -802.942  ...  -1813.9500
# 4       1647.830    1935.800    2047.390    2158.980  ...   1535.0000
# ...          ...         ...         ...         ...  ...         ...
# 7995    1166.250     937.478    1072.700     823.896  ...   1117.7400
# 7996    1478.710     983.911    1262.110    1422.860  ...    984.6340
# 7997    1033.560    1930.380    1057.150    1471.600  ...    888.4080
# 7998    4391.050    1146.820    4473.050    1614.750  ...   5833.7600
# 7999    3336.865    1588.950    5978.190    4523.110  ...   7352.5700
#
#       20140525_N  20140509_N  20140423_N   20140407_N   20140322_N  \
# 0      -1043.160  -1942.4900    267.1380   248.534667   229.931333
# 1       -933.934   -625.3850    120.0590   364.858000   476.972000
# 2        368.622   -429.5890  -1227.8000   304.621000   336.917500
# 3        155.624   -384.2245   -924.0730   432.150000   282.833000
# 4       1959.430   -279.3170   -384.9150  -113.406000  1020.720000
# ...          ...         ...         ...          ...          ...
# 7995    1176.600   1044.1100    706.5960   369.082000   465.843000
# 7996    2128.970   1379.6600   1071.1465   762.633000   485.204000
# 7997    2093.020   1232.1100   1190.8300  1441.460000  1170.880000
# 7998    4047.320   4515.8000    433.1770   277.296000   744.143000
# 7999    3289.860   3729.1500   1994.9800  3647.440000  5299.900000
#
#       20140218_N  20140202_N  20140117_N  20140101_N
# 0       211.3280   -2203.020  -1180.1900     433.906
# 1       220.8780   -2250.000  -1360.5600     524.075
# 2       369.2140   -2202.120  -1772.8350   -1343.550
# 3       298.3200   -2197.360  -1512.0435    -826.727
# 4      1660.6500    -116.801   -568.0500   -1357.140
# ...          ...         ...         ...         ...
# 7995    362.8820     979.795    706.7270     433.659
# 7996    446.7240     771.747   1589.0600     506.936
# 7997   1095.0000    1818.650   2501.7200    1247.770
# 7998   2251.9265    3759.710   2074.0280     388.346
# 7999   5641.5150    5983.130   1249.7100    2424.230
#
# [8000 rows x 30 columns]

# %%
print(train_df.isnull().sum())
# Out:
# Unnamed: 0    0
# ID            0
# class         0
# 20150720_N    0
# 20150602_N    0
# 20150517_N    0
# 20150501_N    0
# 20150415_N    0
# 20150330_N    0
# 20150314_N    0
# 20150226_N    0
# 20150210_N    0
# 20150125_N    0
# 20150109_N    0
# 20141117_N    0
# 20141101_N    0
# 20141016_N    0
# 20140930_N    0
# 20140813_N    0
# 20140626_N    0
# 20140610_N    0
# 20140525_N    0
# 20140509_N    0
# 20140423_N    0
# 20140407_N    0
# 20140322_N    0
# 20140218_N    0
# 20140202_N    0
# 20140117_N    0
# 20140101_N    0
# dtype: int64

# %%
min_vals = x_train.min()
max_vals = x_train.max()

# %%
x_train = train_df[ndvi_columns]
y_train = train_df['class']
print(y_train)
# Out:
# 0            water
# 1            water
# 2            water
# 3            water
# 4            water
#            ...
# 7995    impervious
# 7996    impervious
# 7997    impervious
# 7998    impervious
# 7999    impervious
# Name: class, Length: 8000, dtype: object

# %%
x_test = test_df[ndvi_columns]

# %%
# Apply normalization to training data
x_train = (x_train - min_vals) / (max_vals - min_vals)
    
# Apply the SAME normalization to testing data
x_test = (x_test - min_vals) / (max_vals - min_vals)

# %%
model = LogisticRegression( random_state=42)
model.fit(x_train, y_train)
# Out:
# C:\programming\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
train_predictions = model.predict(x_train)

# %%
training_accuracy = accuracy_score(y_train, train_predictions)
print(training_accuracy)
# Out:
# 0.841875

# %%
test_predictions = model.predict(x_test)

# %%
print(test_predictions)
# Out:
# ['forest' 'forest' 'orchard' ... 'water' 'water' 'grass']

# %%
output_df = pd.DataFrame({
        'ID': test_df['ID'],
        'class': test_predictions
    })

# %%
print(output_df)
# Out:
#         ID    class
# 0        1   forest
# 1        2   forest
# 2        3  orchard
# 3        4     farm
# 4        5   forest
# ...    ...      ...
# 2840  2841    water
# 2841  2842    water
# 2842  2843    water
# 2843  2844    water
# 2844  2845    grass
#
# [2845 rows x 2 columns]

# %%
output_filename = 'logistic_predicted_land_cover.csv'
output_df.to_csv(output_filename, index=False)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RFmodel = RandomForestClassifier(random_state=42)
RFmodel.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rftrain_predictions = RFmodel.predict(x_train)

# %%
rftraining_accuracy = accuracy_score(y_train, rftrain_predictions)
print(rftraining_accuracy)
# Out:
# 1.0

# %%
rftest_predictions = RFmodel.predict(x_test)

# %%
rfoutput_df = pd.DataFrame({
        'ID': test_df['ID'],
        'class': rftest_predictions
    })

# %%
rfoutput_filename = 'RF_predicted_land_cover.csv'
rfoutput_df.to_csv(rfoutput_filename, index=False)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
GNBmodel = GaussianNB()
GNBmodel.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
gnbtrain_predictions = GNBmodel.predict(x_train)

# %%
gnbtraining_accuracy = accuracy_score(y_train, gnbtrain_predictions)
print(gnbtraining_accuracy)
# Out:
# 0.842625

# %%
gnbtest_predictions = GNBmodel.predict(x_test)

# %%
gnboutput_df = pd.DataFrame({
        'ID': test_df['ID'],
        'class': gnbtest_predictions
    })

# %%
gnboutput_filename = 'GNB_predicted_land_cover.csv'
gnboutput_df.to_csv(gnboutput_filename, index=False)

# %%
le = LabelEncoder()
y_train_enc = le.fit_transform(train_df["class"])

# %%
xgb_model = XGBClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=6,
    random_state=42,
    eval_metric='mlogloss'
)
xgb_model.fit(x_train, y_train_enc)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
xgbtrain_predictions = xgb_model.predict(x_train)

# %%
xgbtraining_accuracy = accuracy_score(y_train_enc, xgbtrain_predictions)
print(xgbtraining_accuracy)
# Out:
# 0.9985

# %%
xgbtest_predictions_enc = xgb_model.predict(x_test)

# %%
xgbtest_predictions=le.inverse_transform(xgbtest_predictions_enc)

# %%
print(xgbtest_predictions)
# Out:
# ['forest' 'forest' 'forest' ... 'water' 'impervious' 'impervious']

# %%
xgboutput_df = pd.DataFrame({
        'ID': test_df['ID'],
        'class': xgbtest_predictions
    })

# %%
xgboutput_filename = 'XGB_predicted_land_cover.csv'
xgboutput_df.to_csv(xgboutput_filename, index=False)
